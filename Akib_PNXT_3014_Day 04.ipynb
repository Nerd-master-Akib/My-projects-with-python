# %%
import pandas as pd
titanic = df = pd.read_csv('c:/Users/Win Technology/Documents/dataset_1_Pynext.csv')#loaded the titanic sataset
print(titanic.shape) #shape,column,dtypes,head,tails,sample 
print(titanic.columns)
print(titanic.dtypes)
print(titanic.head()) 
print(titanic.tail())
print(titanic.sample(5))  
# indexing and slicing
titanic['Pclass']
titanic['Fare']
titanic.head(10)
titanic.tail(5)
titanic.where(titanic['Age'] < 18)
# Filtering
titanic.where(titanic['Fare'] > 50)
print(titanic.query('Pclass = "1st"' and 'Sex == "female"' and 'Survived == " Yes"'))
print(titanic.query('Pclass = "3rd"' and 'Sex == "male"' and' Survived == "No"'))
# Adding/Modifying columns
titanic = df 
df['FamilySize'] = (df['Siblings/Spouses Aboard']+df['Parents/Children Aboard']) + 1
print(df['FamilySize'])
df['Create IsChild'] = df['Age'] < 18
print(df['Create IsChild'])
# Drop and add Rows 
print(df.dropna(subset = ['Age'])) 
df.loc["fictional passenger"] = {"Age": 20, "Pclass": 3 , "Fare": 7.25 , "Survived": "No"}
print(df)
#Grouping and Aggregation
print(df.groupby('Pclass')["Fare"].mean())
print(df.groupby('Sex')["Survived"].count())
#Sorting
df.sort_values(by = 'Fare', ascending = False)
df.sort_values(by = 'Age')
# Out:
# (887, 7)
# Index(['Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare', 'Survived'],
#       dtype='object')
# Pclass                      object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# Survived                    object
# dtype: object
#   Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0    3rd    male  22.0                        1                        0
# 1    1st  female  38.0                        1                        0
# 2    3rd  female  26.0                        0                        0
# 3    1st  female  35.0                        1                        0
# 4    3rd    male  35.0                        0                        0
#
#       Fare Survived
# 0   7.2500       No
# 1  71.2833      Yes
# 2   7.9250      Yes
# 3  53.1000      Yes
# ...

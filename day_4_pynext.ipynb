# %% [markdown]
# ### Panda introduction

# %%
import pandas as pd
s = pd.Series([10, 20, 30])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import numpy as np
numarr1 = np.array([1, 2, 3, 4, 5])
pd.Series(numarr1, index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# #### Shape introduction

# %%
import numpy as np
numarr1 = np.array([1, 2, 3, 4, 5])
pd.Series(numarr1, index=['a', 'b', 'c', 'd', 'e'])
series1 = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
print(series1)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
series1.shape
series1.ndim
series1.size
# Out:
# 5

# %%
series1.shape
# Out:
# (5,)

# %%
series1[0:2:1]
# Out:
# a    10
# b    20
# dtype: int64

# %%
series1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
series1['e']
# Out:
# np.int64(50)

# %%
series2 = pd.Series([10, 20, 30], index=['1', '2', '3'])
print(series2)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
series2['3']= '2'
print(series2)
# Out:
# 1     2
# 3     2
# 2    50
# dtype: object

# %%
series2.index = ['a','b','c']
print(series2)
# Out:
# a     2
# b     2
# c    50
# dtype: object

# %%
name = ['John', 'Jane', 'Doe', 'Alice', 'Bob']
age = [25, 30, 22, 28, 35]
Inc = [50000, 60000, 55000, 70000, 65000]
dict1 = {'Name': name, 'Age': age, 'Income': Inc}
print(dict1)
print(pd.DataFrame(dict1))
# Out:
# {'Name': ['John', 'Jane', 'Doe', 'Alice', 'Bob'], 'Age': [25, 30, 22, 28, 35], 'Income': [50000, 60000, 55000, 70000, 65000]}
#     Name  Age  Income
# 0   John   25   50000
# 1   Jane   30   60000
# 2    Doe   22   55000
# 3  Alice   28   70000
# 4    Bob   35   65000

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
lis1 = [i for i in range(1,6)]
print(lis1)
# Out:
# [1, 2, 3, 4, 5]

# %%
df1 = pd.DataFrame(dict1)
print(df1)
# Out:
#     Name  Age  Income
# 0   John   25   50000
# 1   Jane   30   60000
# 2    Doe   22   55000
# 3  Alice   28   70000
# 4    Bob   35   65000

# %%
df1 = pd.DataFrame(dict1, index = [i for i in range(1,6)])
print(df1)
# Out:
#     Name  Age  Income
# 1   John   25   50000
# 2   Jane   30   60000
# 3    Doe   22   55000
# 4  Alice   28   70000
# 5    Bob   35   65000

# %%
name = pd.Series(['John', 'Jane', 'Doe', 'Alice', 'Bob'])
age = pd.Series([25, 30, 22, 28, 35])
Inc = pd.Series([50000, 60000, 55000, 70000, 65000])
dict3 = {'Name': name, 'Age': age, 'Income': Inc}
print(dict3)
print(pd.DataFrame(dict3))
# Out:
# {'Name': 0     John
# 1     Jane
# 2      Doe
# 3    Alice
# 4      Bob
# dtype: object, 'Age': 0    25
# 1    30
# 2    22
# 3    28
# 4    35
# dtype: int64, 'Income': 0    50000
# 1    60000
# 2    55000
# 3    70000
# 4    65000
# dtype: int64}
#     Name  Age  Income
# 0   John   25   50000
# 1   Jane   30   60000
# 2    Doe   22   55000
# 3  Alice   28   70000
# 4    Bob   35   65000

# %%
df = pd.DataFrame(dict1)
print(df)
# Out:
#     Name  Age  Income
# 0   John   25   50000
# 1   Jane   30   60000
# 2    Doe   22   55000
# 3  Alice   28   70000
# 4    Bob   35   65000

# %%
df = df.set_index('ID')
print(df)
# Out:
#     Name  Age  Income
# 0   John   25   50000
# 1   Jane   30   60000
# 2    Doe   22   55000
# 3  Alice   28   70000
# 4    Bob   35   65000

# %%
df['ID'] = [1, 2, 3, 4, 5]  # Add an ID column if not present
df = df.set_index('ID')
print(df)
# Out:
#      Name  Age  Income
# ID
# 1    John   25   50000
# 2    Jane   30   60000
# 3     Doe   22   55000
# 4   Alice   28   70000
# 5     Bob   35   65000

# %%
df.shape
# Out:
# (5, 3)

# %%
print(df.size)
print(df.columns)
print(df.index)
print(df.dtypes)
print(df.values)
# Out:
# 15
# Index(['Name', 'Age', 'Income'], dtype='object')
# Index([1, 2, 3, 4, 5], dtype='int64', name='ID')
# Name      object
# Age        int64
# Income     int64
# dtype: object
# [['John' 25 50000]
#  ['Jane' 30 60000]
#  ['Doe' 22 55000]
#  ['Alice' 28 70000]
#  ['Bob' 35 65000]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Income  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 160.0+ bytes

# %%
df.describe()
# Out:
#              Age       Income
# count   5.000000      5.00000
# mean   28.000000  60000.00000
# std     4.949747   7905.69415
# min    22.000000  50000.00000
# 25%    25.000000  55000.00000
# 50%    28.000000  60000.00000
# 75%    30.000000  65000.00000
# max    35.000000  70000.00000

# %%
df.head(2)
# Out:
#     Name  Age  Income
# ID
# 1   John   25   50000
# 2   Jane   30   60000

# %%
df.tail(2)
# Out:
#      Name  Age  Income
# ID
# 4   Alice   28   70000
# 5     Bob   35   65000

# %%
df.reset_index(inplace=True)  # Reset index to default integer index
print(df)
# Out:
#    ID   Name  Age  Income
# 0   1   John   25   50000
# 1   2   Jane   30   60000
# 2   3    Doe   22   55000
# 3   4  Alice   28   70000
# 4   5    Bob   35   65000

# %%
df.nunique()
# Out:
# ID        5
# Name      5
# Age       5
# Income    5
# dtype: int64

# %%
df.sample()
# Out:
#    ID  Name  Age  Income
# 0   1  John   25   50000

# %%
#slicing
df[0:2]  # Slicing the first two rows
# Out:
#    ID  Name  Age  Income
# 0   1  John   25   50000
# 1   2  Jane   30   60000

# %%
#slicing
df[1:4:2]  # Slicing with step
# Out:
#    ID   Name  Age  Income
# 1   2   Jane   30   60000
# 3   4  Alice   28   70000

# %%
df['Age'] # Accessing a specific column
# Out:
# 0    25
# 1    30
# 2    22
# 3    28
# 4    35
# Name: Age, dtype: int64

# %%
df['Gender'] = ['Male', 'Female', 'Female','Male','Male']
print(df)
# Out:
#    ID   Name  Age  Income  Gender
# 0   1   John   25   50000    Male
# 1   2   Jane   30   60000  Female
# 2   3    Doe   22   55000  Female
# 3   4  Alice   28   70000    Male
# 4   5    Bob   35   65000    Male

# %%
df.iloc[2] # Accessing a specific row by index position
# Out:
# ID             3
# Name         Doe
# Age           22
# Income     55000
# Gender    Female
# Name: 2, dtype: object

# %%
df.iloc[0:2]  # Accessing rows by index position
# Out:
#    ID  Name  Age  Income  Gender
# 0   1  John   25   50000    Male
# 1   2  Jane   30   60000  Female

# %%
df.iloc[0:4:2]  # Accessing rows with step
# Out:
#    ID  Name  Age  Income  Gender
# 0   1  John   25   50000    Male
# 2   3   Doe   22   55000  Female

# %%
df.iloc[0:2,3]  # Accessing specific rows and columns
# Out:
# 0    50000
# 1    60000
# Name: Income, dtype: int64

# %%
import pandas as pd
titanic = pd.read_csv('c:/Users/Win Technology/Documents/dataset_1_Pynext.csv')
titanic
# Out:
#     Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0      3rd    male  22.0                        1                        0
# 1      1st  female  38.0                        1                        0
# 2      3rd  female  26.0                        0                        0
# 3      1st  female  35.0                        1                        0
# 4      3rd    male  35.0                        0                        0
# ..     ...     ...   ...                      ...                      ...
# 882    2nd    male  27.0                        0                        0
# 883    1st  female  19.0                        0                        0
# 884    3rd  female   7.0                        1                        2
# 885    1st    male  26.0                        0                        0
# 886    3rd    male  32.0                        0                        0
#
#         Fare Survived
# 0     7.2500       No
# ...

# %%
titanic.describe()
# Out:
#               Age  Siblings/Spouses Aboard  Parents/Children Aboard       Fare
# count  887.000000               887.000000               887.000000  887.00000
# mean    29.471443                 0.525366                 0.383315   32.30542
# std     14.121908                 1.104669                 0.807466   49.78204
# min      0.420000                 0.000000                 0.000000    0.00000
# 25%     20.250000                 0.000000                 0.000000    7.92500
# 50%     28.000000                 0.000000                 0.000000   14.45420
# 75%     38.000000                 1.000000                 0.000000   31.13750
# max     80.000000                 8.000000                 6.000000  512.32920

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Pclass                   887 non-null    object
#  1   Sex                      887 non-null    object
#  2   Age                      887 non-null    float64
#  3   Siblings/Spouses Aboard  887 non-null    int64
#  4   Parents/Children Aboard  887 non-null    int64
#  5   Fare                     887 non-null    float64
#  6   Survived                 887 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 48.6+ KB

# %%
titanic.tail(10)
# Out:
#     Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 877    3rd    male  33.0                        0                        0
# 878    3rd  female  22.0                        0                        0
# 879    2nd    male  28.0                        0                        0
# 880    3rd    male  25.0                        0                        0
# 881    3rd  female  39.0                        0                        5
# 882    2nd    male  27.0                        0                        0
# 883    1st  female  19.0                        0                        0
# 884    3rd  female   7.0                        1                        2
# 885    1st    male  26.0                        0                        0
# 886    3rd    male  32.0                        0                        0
#
#         Fare Survived
# 877   7.8958       No
# 878  10.5167       No
# 879  10.5000       No
# 880   7.0500       No
# 881  29.1250       No
# ...

# %%
titanic.head(10)
# Out:
#   Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0    3rd    male  22.0                        1                        0
# 1    1st  female  38.0                        1                        0
# 2    3rd  female  26.0                        0                        0
# 3    1st  female  35.0                        1                        0
# 4    3rd    male  35.0                        0                        0
# 5    3rd    male  27.0                        0                        0
# 6    1st    male  54.0                        0                        0
# 7    3rd    male   2.0                        3                        1
# 8    3rd  female  27.0                        0                        2
# 9    2nd  female  14.0                        1                        0
#
#       Fare Survived
# 0   7.2500       No
# 1  71.2833      Yes
# 2   7.9250      Yes
# 3  53.1000      Yes
# 4   8.0500       No
# 5   8.4583       No
# ...

# %%
titanic['Survived'] # Accessing a specific column
# Out:
# 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 882      No
# 883     Yes
# 884      No
# 885     Yes
# 886      No
# Name: Survived, Length: 887, dtype: object

# %%
titanic['Survived'] == ' Yes'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 882    False
# 883     True
# 884    False
# 885     True
# 886    False
# Name: Survived, Length: 887, dtype: bool

# %%
(titanic['Survived'] == ' Yes').sum()
# Out:
# np.int64(342)

# %%
(titanic['Survived'] == 'No').sum()
# Out:
# np.int64(545)

# %%
titanic.where(titanic['Age'] < 75)
# Out:
#     Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0      3rd    male  22.0                      1.0                      0.0
# 1      1st  female  38.0                      1.0                      0.0
# 2      3rd  female  26.0                      0.0                      0.0
# 3      1st  female  35.0                      1.0                      0.0
# 4      3rd    male  35.0                      0.0                      0.0
# ..     ...     ...   ...                      ...                      ...
# 882    2nd    male  27.0                      0.0                      0.0
# 883    1st  female  19.0                      0.0                      0.0
# 884    3rd  female   7.0                      1.0                      2.0
# 885    1st    male  26.0                      0.0                      0.0
# 886    3rd    male  32.0                      0.0                      0.0
#
#         Fare Survived
# 0     7.2500       No
# ...

# %%
titanic.query('Pclass == "1st" and Survived == " Yes"' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 titanic.query('Pclass == "1st" and Survived == " Yes"' )
#
# NameError: name 'titanic' is not defined

# %%
titanic.rename(columns = {'Pclass': 'Class'}, inplace=True)  # Correcting the column name
titanic
# Out:
#     Class     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0     3rd    male  22.0                        1                        0
# 1     1st  female  38.0                        1                        0
# 2     3rd  female  26.0                        0                        0
# 3     1st  female  35.0                        1                        0
# 4     3rd    male  35.0                        0                        0
# ..    ...     ...   ...                      ...                      ...
# 882   2nd    male  27.0                        0                        0
# 883   1st  female  19.0                        0                        0
# 884   3rd  female   7.0                        1                        2
# 885   1st    male  26.0                        0                        0
# 886   3rd    male  32.0                        0                        0
#
#         Fare Survived
# 0     7.2500       No
# 1    71.2833      Yes
# ...

# %%
new_titanic = titanic = df
new_titanic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 new_titanic = titanic = df
#       2 new_titanic
#
# NameError: name 'df' is not defined

# %%
titanic.groupby("Survived")['Age'].count()
# Out:
# Survived
#  Yes    342
# No      545
# Name: Age, dtype: int64

# %%
titanic['New_Fare'] = titanic['Fare']*100
titanic
# Out:
#     Class     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0     3rd    male  22.0                        1                        0
# 1     1st  female  38.0                        1                        0
# 2     3rd  female  26.0                        0                        0
# 3     1st  female  35.0                        1                        0
# 4     3rd    male  35.0                        0                        0
# ..    ...     ...   ...                      ...                      ...
# 882   2nd    male  27.0                        0                        0
# 883   1st  female  19.0                        0                        0
# 884   3rd  female   7.0                        1                        2
# 885   1st    male  26.0                        0                        0
# 886   3rd    male  32.0                        0                        0
#
#         Fare Survived  New_Fare
# 0     7.2500       No    725.00
# ...

# %%
dict20 = {
    'Name' : ['a','v',None,'s'],
    'Age' : [10,20,30,40]
}
df3 = pd.DataFrame(dict20)
df3
# Out:
#    Name  Age
# 0     a   10
# 1     v   20
# 2  None   30
# 3     s   40

# %%
titanic.sort_values(by='Age')
# Out:
#     Pclass     Sex    Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 799    3rd    male   0.42                        0                        1
# 751    2nd    male   0.67                        1                        1
# 641    3rd  female   0.75                        2                        1
# 466    3rd  female   0.75                        2                        1
# 77     2nd    male   0.83                        0                        2
# ..     ...     ...    ...                      ...                      ...
# 115    3rd    male  70.50                        0                        0
# 490    1st    male  71.00                        0                        0
# 95     1st    male  71.00                        0                        0
# 847    3rd    male  74.00                        0                        0
# 627    1st    male  80.00                        0                        0
#
#         Fare Survived
# 799   8.5167      Yes
# ...
